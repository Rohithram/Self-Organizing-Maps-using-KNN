# %% [markdown]
# # Unit Testing Bayeschangepoint Detection

# %%
import writefile_run as writefile_run

# %%
% matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile_run unit_test_bayes_sprint1.py
#
# import pandas as pd
# import numpy as np
# import os
# import bayeschangept_sprint1 as bayeschangept
# import warnings
# warnings.filterwarnings('ignore')
# Out:
# /home/rohithram/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Use scipy logsumexp().

# %%
# %%writefile_run unit_test_bayes_sprint1.py -a
#
#
# assetno = ['1']
# con = '52.173.76.89:4242'
# src_type =  'opentsdb'
# param = ['FE-001.DRIVEENERGY']
# from_timestamp = 1520402214
# to_timestamp = 1520407294

# %%
kwargs = lambda :{
            'assetno':assetno,
            'from_timestamp':from_timestamp,
            'to_timestamp':to_timestamp,
            'con':con,
            'para_list':param,
            'source_type':src_type,
            'table_name':'',
            'qry_str':'',
            'impute_fill_method':'forward',
            'down_sampling_method':None,
            'down_sampling_window':None,
            'freq':None,
            'resample_fill_method':None,
            'to_resample':None,
            'to_impute':True,
            'thres_prob':0.5,
            'samples_to_wait':10,
            'expected_run_length':100
        }

# %%
def preparecsvtoread(filepath,filename,target_dir,assetno='1',n_rows=None,has_time=True):
    if(n_rows is not None):
        df  = pd.read_csv(filepath,nrows=n_rows)
    else:
        df = pd.read_csv(filepath)
    df['assetno'] = assetno
    if(has_time!=True):
        start = pd.Timestamp("19700807 08:30-0400")
        end = pd.Timestamp("20170807 17:30-0400")
        index = pd.DatetimeIndex(start=start, end=end, freq="10min")[:n_rows]
        df.insert(0,'timestamp', index) 
        df = df.dropna(axis=1, how='all')
        print(df.head())
    else:
        df = df.rename(columns={df.columns[0]:'timestamp'})
    df['timestamp'] = (pd.to_datetime(df['timestamp'],infer_datetime_format=True).astype(np.int64)/(1e6)).astype(np.int64)
    metric_names = df.columns[1:-1]
    target_filepath = os.path.join(target_dir,filename)
    df.to_csv(target_filepath,index=False)
    return target_filepath,list(metric_names)

# %%
def get_csv_kwargs(infile='./dataset/sample_csv_files/alcohol-demand-log-spirits-consu.csv',
                  filename='alcohol-demand-log-spirits-consu.csv',
                  target_dir='dataset/reader_csv_files/',assetno = ['1'],n_rows=None,has_time=True):
    kwargs1 = kwargs()
    
    con,param = preparecsvtoread(filepath=infile,filename=filename,target_dir=target_dir,assetno=assetno[0],
                                 n_rows=n_rows,has_time=has_time)
    kwargs1['con'] = con
    kwargs1['source_type'] = 'csv'
    kwargs1['from_timestamp']=-int(2**63)
    kwargs1['to_timestamp']=int(2**63)
    kwargs1['para_list'] = param
    
    return kwargs1

# %%
keys = ['thres_prob','samples_to_wait','expected_run_length']

# %% [markdown]
# ## Test 1 :
# #### Testing with parameters being empty quotes

# %%
# %%writefile_run unit_test_bayes_sprint1.py -a
#
# kwargs1 = kwargs()
# for key in keys:
#     kwargs1[key]=''
#     res = bayeschangept.call(**kwargs1)
#     print(res)
# Out:
# {'code': '400', 'status': 'Bad Request', 'message': "should be of type <class 'float'>", 'data': {'argument': 'pthres', 'value': ''}}
# {'code': '400', 'status': 'Bad Request', 'message': "should be of type <class 'float'>", 'data': {'argument': 'pthres', 'value': ''}}
# {'code': '400', 'status': 'Bad Request', 'message': "should be of type <class 'float'>", 'data': {'argument': 'pthres', 'value': ''}}

# %% [markdown]
# ## Test 2 :
# #### Testing missing parameters :

# %%
# %%writefile_run unit_test_bayes_sprint1.py -a
#
#
# kwargs1 = kwargs()
# for key in keys:
#     del kwargs1[key]
#     res = bayeschangept.call(**kwargs1)
#     print(res)
# Out:
# Data reader initialised
#
# {'code': '404', 'status': 'Not Found', 'message': "(<class 'KeyboardInterrupt'>, KeyboardInterrupt(), <traceback object at 0x7f81fb231888>)"}
# Data reader initialised
#
# {'code': '404', 'status': 'Not Found', 'message': "(<class 'KeyboardInterrupt'>, KeyboardInterrupt(), <traceback object at 0x7f81fb231ac8>)"}
# Data reader initialised
#
# {'code': '404', 'status': 'Not Found', 'message': "(<class 'KeyboardInterrupt'>, KeyboardInterrupt(), <traceback object at 0x7f81fb2318c8>)"}

# %% [markdown]
# ## Test 3:
# #### Testing parameter type mismatch

# %%
keys
# Out:
# ['thres_prob', 'samples_to_wait', 'expected_run_length']

# %%
# %%writefile_run unit_test_bayes_sprint1.py -a
#
# kwargs1 = kwargs()
# val = ['2',4.5,'def']
# for i,key in enumerate(keys):
#     kwargs1[key]=val[i]
#     res = bayeschangept.call(**kwargs1)
#     print(res)
# Out:
# {'code': '400', 'status': 'Bad Request', 'message': "should be of type <class 'float'>", 'data': {'argument': 'pthres', 'value': '2'}}
# {'code': '400', 'status': 'Bad Request', 'message': "should be of type <class 'float'>", 'data': {'argument': 'pthres', 'value': '2'}}
# {'code': '400', 'status': 'Bad Request', 'message': "should be of type <class 'float'>", 'data': {'argument': 'pthres', 'value': '2'}}

# %% [markdown]
# ### User Defined Test Case:
# #### Testing the fact that probability threshold must be between 0 and 1

# %%
kwargs1 = kwargs()
val = [5,4,100]
for i,key in enumerate(keys):
    kwargs1[key]=val[i]
    res = bayeschangept.call(**kwargs1)
    print(res)
# Out:
# {'code': '400', 'status': 'Bad Request', 'message': 'probability must be between 0 and 1 and it must be of type int or float', 'data': {'argument': 'pthres', 'value': 5}}
# {'code': '400', 'status': 'Bad Request', 'message': 'probability must be between 0 and 1 and it must be of type int or float', 'data': {'argument': 'pthres', 'value': 5}}
# {'code': '400', 'status': 'Bad Request', 'message': 'probability must be between 0 and 1 and it must be of type int or float', 'data': {'argument': 'pthres', 'value': 5}}

# %% [markdown]
# ## Test 4:
# #### Testing Algorithm Logic :
# * Running the algorithm for different values of probability thresholds
# * so expected o/p behaviour expected is as we increase the probability threshold the no of anomaly detected reduces and reaches zero when set to $1.0$
# * Default threshold is $0.5$

# %%
# %%writefile_run unit_test_bayes_sprint1.py -a
#
# kwargs1 = get_csv_kwargs()
# pthreses = [0.5,0.0,1.0]
# for i,pthres in enumerate(pthreses):
#     kwargs1['thres_prob']=pthres
#     res = bayeschangept.call(**kwargs1)
#     print(res)
# Out:
# Data reader initialised
#
# Getting the dataset from the reader....
#
# Asset no : 1
#                 assetno  \
# timestamp
# -3.147898e+12      1.0
# -3.137357e+12      1.0
# -3.126816e+12      1.0
# -3.116362e+12      1.0
# -3.105821e+12      1.0
#
#                Alcohol demand (log spirits consumption per head), UK, 1870-1938
# timestamp
# -3.147898e+12                                              1.957
# -3.137357e+12                                              1.979
# -3.126816e+12                                              2.012
# -3.116362e+12                                              2.045
# -3.105821e+12                                              2.056
#
#
# Anomaly detection for AssetNo : 1 , Metric : Alcohol demand (log spirits consumption per head), UK, 1870-1938
#
# Shape of the dataset :
# (207, 2)
# Overview of first five rows of dataset :
# Traceback (most recent call last):
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayeschangept_sprint1.py", line 133, in call
#     data,anom_indexes = anomaly_detector.detect_anomalies()
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 62, in detect_anomalies
#     anom_indexes = self.plotonchangepoints(R,maxes)
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 98, in plotonchangepoints
#     fig,(ax1,ax3) = plt.subplots(3,figsize=[18, 16])
# ValueError: too many values to unpack (expected 2)
# {'code': '500', 'status': 'Unknown Exception', 'message': ValueError('too many values to unpack (expected 2)',)}
# {'code': '400', 'status': 'Bad Request', 'message': 'probability must be between 0 and 1 and it must be of type int or float', 'data': {'argument': 'pthres', 'value': 0.0}}
# {'code': '400', 'status': 'Bad Request', 'message': 'probability must be between 0 and 1 and it must be of type int or float', 'data': {'argument': 'pthres', 'value': 1.0}}

# %% [markdown]
# #### Observe the effect of expected_run_length on the algorithm

# %%
kwargs1['thres_prob'] = 0.5
mean_run_lens = [0,100,10000]
for i,mean_run_len in enumerate(mean_run_lens):
    print('\n Anomaly detection for expected run length  = {}\n'.format(mean_run_len))
    kwargs1['expected_run_length']=mean_run_len
    res = bayeschangept.call(**kwargs1)
    print(res)
# Out:
#  Anomaly detection for expected run length  = 0
#
# Data reader initialised
#
# Getting the dataset from the reader....
#
# Asset no : 1
#                 assetno  \
# timestamp
# -3.147898e+12      1.0
# -3.137357e+12      1.0
# -3.126816e+12      1.0
# -3.116362e+12      1.0
# -3.105821e+12      1.0
#
#                Alcohol demand (log spirits consumption per head), UK, 1870-1938
# timestamp
# -3.147898e+12                                              1.957
# -3.137357e+12                                              1.979
# -3.126816e+12                                              2.012
# -3.116362e+12                                              2.045
# -3.105821e+12                                              2.056
#
#
# Anomaly detection for AssetNo : 1 , Metric : Alcohol demand (log spirits consumption per head), UK, 1870-1938
#
# Shape of the dataset :
# (207, 2)
# Overview of first five rows of dataset :
# {'code': '500', 'status': 'Unknown Exception', 'message': ZeroDivisionError('division by zero',)}
#
#  Anomaly detection for expected run length  = 100
#
# Data reader initialised
# Traceback (most recent call last):
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayeschangept_sprint1.py", line 133, in call
#     data,anom_indexes = anomaly_detector.detect_anomalies()
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 61, in detect_anomalies
#     R,maxes = self.findonchangepoint(data[data.columns[ncol]].values)
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 73, in findonchangepoint
#     oncd.StudentT(0.1, .01, 1, 0))
#   File "/home/rohithram/anaconda3/lib/python3.6/site-packages/bayesian_changepoint_detection/online_changepoint_detection.py", line 17, in online_changepoint_detection
#     H = hazard_func(np.array(range(t+1)))
#   File "/home/rohithram/anaconda3/lib/python3.6/site-packages/bayesian_changepoint_detection/online_changepoint_detection.py", line 40, in constant_hazard
#     return 1/lam * np.ones(r.shape)
# ZeroDivisionError: division by zero
# Getting the dataset from the reader....
#
# Asset no : 1
#                 assetno  \
# timestamp
# -3.147898e+12      1.0
# -3.137357e+12      1.0
# -3.126816e+12      1.0
# -3.116362e+12      1.0
# -3.105821e+12      1.0
#
#                Alcohol demand (log spirits consumption per head), UK, 1870-1938
# timestamp
# -3.147898e+12                                              1.957
# -3.137357e+12                                              1.979
# -3.126816e+12                                              2.012
# -3.116362e+12                                              2.045
# -3.105821e+12                                              2.056
#
#
# Anomaly detection for AssetNo : 1 , Metric : Alcohol demand (log spirits consumption per head), UK, 1870-1938
#
# Shape of the dataset :
# (207, 2)
# Overview of first five rows of dataset :
# Traceback (most recent call last):
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayeschangept_sprint1.py", line 133, in call
#     data,anom_indexes = anomaly_detector.detect_anomalies()
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 62, in detect_anomalies
#     anom_indexes = self.plotonchangepoints(R,maxes)
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 98, in plotonchangepoints
#     fig,(ax1,ax3) = plt.subplots(3,figsize=[18, 16])
# ValueError: too many values to unpack (expected 2)
# {'code': '500', 'status': 'Unknown Exception', 'message': ValueError('too many values to unpack (expected 2)',)}
#
#  Anomaly detection for expected run length  = 10000
#
# Data reader initialised
#
# Getting the dataset from the reader....
#
# Asset no : 1
#                 assetno  \
# timestamp
# -3.147898e+12      1.0
# -3.137357e+12      1.0
# -3.126816e+12      1.0
# -3.116362e+12      1.0
# -3.105821e+12      1.0
#
#                Alcohol demand (log spirits consumption per head), UK, 1870-1938
# timestamp
# -3.147898e+12                                              1.957
# -3.137357e+12                                              1.979
# -3.126816e+12                                              2.012
# -3.116362e+12                                              2.045
# -3.105821e+12                                              2.056
#
#
# Anomaly detection for AssetNo : 1 , Metric : Alcohol demand (log spirits consumption per head), UK, 1870-1938
#
# Shape of the dataset :
# (207, 2)
# Overview of first five rows of dataset :
# Traceback (most recent call last):
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayeschangept_sprint1.py", line 133, in call
#     data,anom_indexes = anomaly_detector.detect_anomalies()
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 62, in detect_anomalies
#     anom_indexes = self.plotonchangepoints(R,maxes)
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 98, in plotonchangepoints
#     fig,(ax1,ax3) = plt.subplots(3,figsize=[18, 16])
# ValueError: too many values to unpack (expected 2)
# {'code': '500', 'status': 'Unknown Exception', 'message': ValueError('too many values to unpack (expected 2)',)}

# %% [markdown]
# ##### Results:
# * As we observed that when expected run length given zero. the algo stops and throws an zero division error as expected/
# * Then as we increase it from zero, we observed that interval between changepoints increased

# %% [markdown]
# ## Test 5:
# #### Testing Algorithm tuning :
# * Trying to change the parameters of algorithm and observe the results obtained
# * Here we try to tune the algo to run faster and as we observe that on increasing expected run length, the sensitivity of detecting changepoints decreases which we saw above case too.

# %%
# %%timeit -n 1 -r 1
# kwargs1 = get_csv_kwargs(infile='./dataset/bearings.csv',filename='bearings.csv',n_rows=5000,has_time=False)
# kwargs1['expected_run_length']= 10000
# res = bayeschangept.call(**kwargs1)
# print(res)

# %% [markdown]
# ## Test 6:
# #### Testing Asset Timeline Logging :

# %%
kwargs1 = get_csv_kwargs()
res = bayeschangept.call(**kwargs1)
print(res)
# Out:
# Data reader initialised
#
# Getting the dataset from the reader....
#
# Asset no : 1
#                 assetno  \
# timestamp
# -3.147898e+12      1.0
# -3.137357e+12      1.0
# -3.126816e+12      1.0
# -3.116362e+12      1.0
# -3.105821e+12      1.0
#
#                Alcohol demand (log spirits consumption per head), UK, 1870-1938
# timestamp
# -3.147898e+12                                              1.957
# -3.137357e+12                                              1.979
# -3.126816e+12                                              2.012
# -3.116362e+12                                              2.045
# -3.105821e+12                                              2.056
#
#
# Anomaly detection for AssetNo : 1 , Metric : Alcohol demand (log spirits consumption per head), UK, 1870-1938
#
# Shape of the dataset :
# (207, 2)
# Overview of first five rows of dataset :
# Traceback (most recent call last):
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayeschangept_sprint1.py", line 133, in call
#     data,anom_indexes = anomaly_detector.detect_anomalies()
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 62, in detect_anomalies
#     anom_indexes = self.plotonchangepoints(R,maxes)
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 98, in plotonchangepoints
#     fig,(ax1,ax3) = plt.subplots(3,figsize=[18, 16])
# ValueError: too many values to unpack (expected 2)
# {'code': '500', 'status': 'Unknown Exception', 'message': ValueError('too many values to unpack (expected 2)',)}

# %% [markdown]
# !['Asset timeline logging 1'](./atl_test2_bayes.png)
# !['Asset timeline logging 2](./atl_test3_bayes.png)

# %% [markdown]
# ## Test 7:
# #### Testing the response from program to follow agreed upon template :

# %%
kwargs1 = get_csv_kwargs()
res = bayeschangept.call(**kwargs1)
print(res)
# Out:
# Data reader initialised
#
# Getting the dataset from the reader....
#
# Asset no : 1
#                 assetno  \
# timestamp
# -3.147898e+12      1.0
# -3.137357e+12      1.0
# -3.126816e+12      1.0
# -3.116362e+12      1.0
# -3.105821e+12      1.0
#
#                Alcohol demand (log spirits consumption per head), UK, 1870-1938
# timestamp
# -3.147898e+12                                              1.957
# -3.137357e+12                                              1.979
# -3.126816e+12                                              2.012
# -3.116362e+12                                              2.045
# -3.105821e+12                                              2.056
#
#
# Anomaly detection for AssetNo : 1 , Metric : Alcohol demand (log spirits consumption per head), UK, 1870-1938
#
# Shape of the dataset :
# (207, 2)
# Overview of first five rows of dataset :
# Traceback (most recent call last):
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayeschangept_sprint1.py", line 133, in call
#     data,anom_indexes = anomaly_detector.detect_anomalies()
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 62, in detect_anomalies
#     anom_indexes = self.plotonchangepoints(R,maxes)
#   File "/home/rohithram/Desktop/internship/sprint1/tsfad/rohithram/rohithram-bayes-changept/Bayesion_changept/bayesian_changept_detector.py", line 98, in plotonchangepoints
#     fig,(ax1,ax3) = plt.subplots(3,figsize=[18, 16])
# ValueError: too many values to unpack (expected 2)
# {'code': '500', 'status': 'Unknown Exception', 'message': ValueError('too many values to unpack (expected 2)',)}

# %% [markdown]
# ## Test 8:
# #### Testing No Data exception :
# * To get empty dataframe we set from and to timestamp to be not in range of the timestamps in dataset analysed

# %%
kwargs1 = get_csv_kwargs()
kwargs1['from_timestamp'] = int(2**60)
kwargs1['to_timestamp'] = int(2**63)
res = bayeschangept.call(**kwargs1)
print(res)
# Out:
# Data reader initialised
#
# {'code': '404', 'status': 'Not Found', 'message': 'Empty DataFrame!'}

# %% [markdown]
# ## Test 9:
# #### Testing Database connectivity  exception :
# * To test this we edit the db properties and run the algo

# %%
import reader_writer.db_properties as db_properties
import reader_writer.writer_configs as writer_configs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-0c0d2b70caa6> in <module>()
# ----> 1 import reader_writer.db_properties as db_properties
#       2 import reader_writer.writer_configs as writer_configs
#
# ModuleNotFoundError: No module named 'reader_writer'

# %%
writer_configs.table_name = 'f'

# %%
db_properties.db_connection

# %% [markdown]
# ### We change the db name and we expect a database error as shown below

# %%
db_properties.db_connection['dbname'] = 'eg'

# %%
kwargs1 = get_csv_kwargs()
res = bayeschangept.call(**kwargs1)
print(res)

# %% [markdown]
# ### Now we try to change the password of db properties and observe the exception handled

# %%
db_properties.db_connection['password']='fef'

# %%
kwargs1 = get_csv_kwargs()
res = bayeschangept.call(**kwargs1)
print(res)

# %%
# %%writefile_run reader_writer/db_properties.py
#
# db_connection = {'dbname': 'Cerebra',
#  'host': '127.0.0.1',
#  'password': 'givemeachance',
#  'port': '5432',
#  'user': 'postgres'}

# %% [markdown]
# ### Now we change the table name in which we are writing, and we observe that relation doesn't exist as seen below

# %%
writer_configs.table_name = 'ffee'

# %%
kwargs1 = get_csv_kwargs()
res = bayeschangept.call(**kwargs1)
print(res)

# %%
writer_configs.table_name = 'public.log_asset_timeline'

# %% [markdown]
# ## Test 10:
# #### Testing random exceptions :

# %%
kwargs1 = get_csv_kwargs()

res = bayeschangept.call(**kwargs1)
print(res)

# %% [markdown]
# ## Test 11:
# #### Testing High Performance :

# %%
# %%timeit -n 1 -r 1
kwargs1 = get_csv_kwargs(infile='./dataset/bearings.csv',filename='bearings.csv',n_rows=10000,has_time=False)
res = bayeschangept.call(**kwargs1)
print(res)
# Out:
#                   timestamp      0      1      2      3      4      5      6  \
# 0 1970-08-07 08:30:00-04:00  0.032 -0.156  0.027  0.027  0.002 -0.122 -0.034
# 1 1970-08-07 08:40:00-04:00 -0.071 -0.107  0.000  0.051 -0.178 -0.132 -0.078
# 2 1970-08-07 08:50:00-04:00 -0.132 -0.042 -0.044  0.012 -0.093 -0.120 -0.183
# 3 1970-08-07 09:00:00-04:00 -0.129 -0.122  0.002  0.037 -0.093 -0.288 -0.156
# 4 1970-08-07 09:10:00-04:00  0.022 -0.129 -0.144 -0.088 -0.024 -0.083 -0.129
#
#        7 assetno
# 0 -0.151       1
# 1 -0.051       1
# 2 -0.100       1
# 3 -0.090       1
# 4 -0.098       1
# Data reader initialised
#
# Getting the dataset from the reader....
#
# Asset no : 1
#                assetno      0      1      2      3      4      5      6      7
# timestamp
# 1.888020e+10      1.0  0.032 -0.156  0.027  0.027  0.002 -0.122 -0.034 -0.151
# 1.888080e+10      1.0 -0.071 -0.107  0.000  0.051 -0.178 -0.132 -0.078 -0.051
# 1.888140e+10      1.0 -0.132 -0.042 -0.044  0.012 -0.093 -0.120 -0.183 -0.100
# 1.888200e+10      1.0 -0.129 -0.122  0.002  0.037 -0.093 -0.288 -0.156 -0.090
# 1.888260e+10      1.0  0.022 -0.129 -0.144 -0.088 -0.024 -0.083 -0.129 -0.098
#
#
# Anomaly detection for AssetNo : 1 , Metric : 0
#
# Shape of the dataset :
# (10000, 9)
# Overview of first five rows of dataset :
#  No of Anomalies detected = 9
#
# Anomaly detection for AssetNo : 1 , Metric : 1
#
# Shape of the dataset :
# (10000, 9)
# Overview of first five rows of dataset :
#  No of Anomalies detected = 5
#
# Anomaly detection for AssetNo : 1 , Metric : 2
#
# Shape of the dataset :
# (10000, 9)
# Overview of first five rows of dataset :
#  No of Anomalies detected = 19
#
# Anomaly detection for AssetNo : 1 , Metric : 3
#
# Shape of the dataset :
# (10000, 9)
# Overview of first five rows of dataset :
#  No of Anomalies detected = 21
#
# Anomaly detection for AssetNo : 1 , Metric : 4
#
# Shape of the dataset :
# (10000, 9)
# Overview of first five rows of dataset :
#  No of Anomalies detected = 1
#
# Anomaly detection for AssetNo : 1 , Metric : 5
#
# Shape of the dataset :
# (10000, 9)
# Overview of first five rows of dataset :
#  No of Anomalies detected = 0
#
# Anomaly detection for AssetNo : 1 , Metric : 6
#
# Shape of the dataset :
# (10000, 9)
# Overview of first five rows of dataset :
#  No of Anomalies detected = 4
#
# Anomaly detection for AssetNo : 1 , Metric : 7
#
# Shape of the dataset :
# (10000, 9)
# Overview of first five rows of dataset :
#  No of Anomalies detected = 5
# Postgres writer initialised
#
# Database error : could not connect to server: Connection refused
# 	Is the server running on host "127.0.0.1" and accepting
# 	TCP/IP connections on port 5432?
#
# {'code': '441', 'status': 'Database error', 'message': 'could not connect to server: Connection refused\n\tIs the server running on host "127.0.0.1" and accepting\n\tTCP/IP connections on port 5432?\n'}
# 4min 37s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ####  We observe that for running oddly $5000$ datapoints for $8$ metric names it takes around $4$ minutes $3$ seconds to run.
# * I believe that reason for this timing is the algo computes the matrix of order of $NxN$ where $N$ is the size of dataset.
# * So it takes lot of time to compute that

# %% [markdown]
# # Conclusion:
# * Hence we observe that **Bayesian Changepoint Detection** works well only on level shifts or variational shift datasets over outlier or surge,sag datasets
